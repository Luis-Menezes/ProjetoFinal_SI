# %%
import torch
from torchvision import models
import torch.nn as nn

# Create ResNet18 with the correct number of output classes (2) to match the checkpoint
model = models.resnet18(num_classes=2)

# load with map_location and allow missing/unexpected keys to avoid RuntimeError
checkpoint = torch.load("pytorch_model.bin", map_location=torch.device('cpu'))
model.load_state_dict(checkpoint, strict=False)

# Move model to available device and set to eval mode
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = model.to(device)
# model.eval()

# %%
from torchvision import transforms

preprocess = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("cashbowman/ai-generated-images-vs-real-images")

print("Path to dataset files:", path)
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/cashbowman/ai-generated-images-vs-real-images?dataset_version_number=1...
# 100%|██████████| 476M/476M [00:43<00:00, 11.4MB/s]
# Extracting files...
# Path to dataset files: /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1

# %%
import zipfile
from pathlib import Path
from PIL import Image
import torch
import torch.nn.functional as F
from collections import Counter

# ...existing code...

# Evaluate model on images found under `path`
data_path = Path(path)  # `path` comes from your kagglehub download cell

# If dataset is a zip, extract it next to the zip
if data_path.is_file() and data_path.suffix == ".zip":
    extract_dir = data_path.with_suffix("")
    if not extract_dir.exists():
        with zipfile.ZipFile(data_path, "r") as z:
            z.extractall(extract_dir)
    data_path = extract_dir

if not data_path.exists():
    raise FileNotFoundError(f"Dataset path not found: {data_path}")

# Find image files and possible class folders
IMG_EXTS = {".jpg", ".jpeg", ".png", ".bmp"}
subdirs = [p for p in data_path.iterdir() if p.is_dir()]
if subdirs:
    classes = sorted([d.name for d in subdirs])
    image_files = [p for d in subdirs for p in d.rglob("*") if p.suffix.lower() in IMG_EXTS]
else:
    classes = []
    image_files = [p for p in data_path.rglob("*") if p.suffix.lower() in IMG_EXTS]

if not image_files:
    print("No images found under", data_path)
else:
    device = next(model.parameters()).device if any(True for _ in model.parameters()) else torch.device("cpu")
    totals = 0
    correct = 0
    per_class = Counter()
    per_class_tot = Counter()

    for img_path in image_files:
        img = Image.open(img_path).convert("RGB")
        tensor = preprocess(img).unsqueeze(0).to(device)

        with torch.no_grad():
            out = model(tensor)

            # Binary output (single logit)
            if out.shape[1] == 1:
                prob_pos = torch.sigmoid(out).item()
                pred_idx = 1 if prob_pos > 0.5 else 0
                pred_label = classes[pred_idx] if len(classes) >= 2 else str(pred_idx)
                conf = prob_pos if pred_idx == 1 else 1.0 - prob_pos

            # Multi-class and number of outputs matches folder classes
            elif len(classes) > 0 and out.shape[1] == len(classes):
                probs = F.softmax(out, dim=1)
                conf, idx = probs.max(dim=1)
                pred_idx = int(idx.item())
                pred_label = classes[pred_idx]
                conf = float(conf.item())

            # Otherwise fallback to imagenet-like labels_file
            else:
                probs = F.softmax(out, dim=1)
                conf, idx = probs.max(dim=1)
                pred_idx = int(idx.item())
                pred_label = labels_file[pred_idx] if pred_idx < len(labels_file) else str(pred_idx)
                conf = float(conf.item())

        # True label from parent folder if available
        true_label = img_path.parent.name if img_path.parent != data_path else None

        print(f"{img_path} | true: {true_label} | pred: {pred_label} (conf {conf:.3f})")

        if true_label is not None:
            totals += 1
            per_class_tot[true_label] += 1
            if true_label == pred_label:
                correct += 1
                per_class[true_label] += 1

    if totals > 0:
        acc = correct / totals
        print(f"\nOverall accuracy (using parent-folder labels): {acc:.4f} ({correct}/{totals})")
        print("Per-class accuracy:")
        for c in sorted(per_class_tot):
            print(f"  {c}: {per_class[c]}/{per_class_tot[c]} = {per_class[c]/per_class_tot[c]:.4f}")
    else:
        print("\nNo parent-folder labels found -> accuracy not computed. Only predictions printed.")
# Out:
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/a4411c44-c1cc-45ca-bf4b-2ecaf5172ba8.jpg | true: AiArtData | pred: RealArt (conf 0.942)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/ai-generated-photos-aurel-manea-1.jpg | true: AiArtData | pred: RealArt (conf 0.938)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/images12.jpg | true: AiArtData | pred: RealArt (conf 0.944)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/230726115314-01-lensa-selfie.jpg | true: AiArtData | pred: RealArt (conf 0.957)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/nvidia_ai.png | true: AiArtData | pred: RealArt (conf 0.941)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/c6cd1ba0-f067-4ca6-9ea2-692684db2b58_hero-ai-portrait-enhancer.jpg | true: AiArtData | pred: RealArt (conf 0.930)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/elephant_topper_fallback.cb6ee071.png | true: AiArtData | pred: RealArt (conf 0.924)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/tiger4.jpg | true: AiArtData | pred: RealArt (conf 0.931)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/Israeli-artist1.jpeg | true: AiArtData | pred: RealArt (conf 0.964)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/images52.jpg | true: AiArtData | pred: RealArt (conf 0.941)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/dreamstime_m_130821195-1.jpg | true: AiArtData | pred: RealArt (conf 0.931)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/AI-generated-landscape-708x400.jpg | true: AiArtData | pred: RealArt (conf 0.921)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/name620-e1680453801646.png | true: AiArtData | pred: RealArt (conf 0.950)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/Ej6jaxYtzcL24kFW7kmKYC.jpg | true: AiArtData | pred: RealArt (conf 0.947)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/morning-sunrise-scenery-lake-landscape-ai-art-nature.jpg | true: AiArtData | pred: RealArt (conf 0.938)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/two-landscape-designs-of-yard-made-by-ai-landscape-generator.jpg | true: AiArtData | pred: RealArt (conf 0.907)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/artificial-intelligence-AI-art402x.png | true: AiArtData | pred: RealArt (conf 0.921)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/ai-header-4.jpg | true: AiArtData | pred: RealArt (conf 0.923)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/zjgkiTBuW5pPg4P7rV8u_4x.jpg | true: AiArtData | pred: RealArt (conf 0.946)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/eEaTGSQwrmwcAzTDoxJc.jpg | true: AiArtData | pred: RealArt (conf 0.929)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/AI-generated-images-art-.jpg | true: AiArtData | pred: RealArt (conf 0.930)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/beautiful-faces.png | true: AiArtData | pred: RealArt (conf 0.936)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/ai-generated-7820332_1280.jpg | true: AiArtData | pred: RealArt (conf 0.921)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/robot-art-for-web-1180x560.jpg | true: AiArtData | pred: RealArt (conf 0.950)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/Simon_HERO.png | true: AiArtData | pred: RealArt (conf 0.963)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/jesus-dunking-scaled.jpg | true: AiArtData | pred: RealArt (conf 0.945)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/xATrJT1OBHIRSWYpTL8t--1--Z5XOZ_4x.jpg | true: AiArtData | pred: RealArt (conf 0.937)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/0EAwg7WIIMhgnSfLf.png | true: AiArtData | pred: RealArt (conf 0.943)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/il_570xN.4641411301_ngcf.jpg | true: AiArtData | pred: RealArt (conf 0.925)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/6487517289657f25a1e7febf_How20Generative20AI20Works20to20Create20AI20Generated20Photos.jpg | true: AiArtData | pred: RealArt (conf 0.954)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/hassan-ragab-cairo-sketches-midjourney-ai-architecture-hero_dezeen_1704_col_0.jpg | true: AiArtData | pred: RealArt (conf 0.914)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/midjourney-images-6.jpg | true: AiArtData | pred: RealArt (conf 0.954)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/3048941-inline-i-2-why-google-deep-dreams-of-dogs.jpg | true: AiArtData | pred: RealArt (conf 0.946)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/midjourney_inpainting_demo-1.png | true: AiArtData | pred: RealArt (conf 0.937)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/65523f91e3679a1ab2eed021_face_of_data_art_kirell_benzi.jpg | true: AiArtData | pred: RealArt (conf 0.909)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/history-of-AI-art.jpg | true: AiArtData | pred: RealArt (conf 0.927)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/midjourney_trump_pope_dance_ai_fake_image.png | true: AiArtData | pred: RealArt (conf 0.932)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/images89.jpg | true: AiArtData | pred: RealArt (conf 0.932)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/1-trippy-cubism-psychedelic-fun-cocktails-mojitos-ai-generated-olfactoart-studio.jpg | true: AiArtData | pred: RealArt (conf 0.886)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/52285b755ff9e3869fac20294bfe1fc1.jpg | true: AiArtData | pred: RealArt (conf 0.940)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/word-image-288-1.png | true: AiArtData | pred: RealArt (conf 0.936)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/pe-How-To-Use-AI-Images-Good-Bad-Review-Bard-Bing-ChatGPT-Guide-Paul-Reiffer.jpg | true: AiArtData | pred: RealArt (conf 0.944)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/76480055-12619627-image-a-40_1697122533354.jpg | true: AiArtData | pred: RealArt (conf 0.938)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/aiart.jpg | true: AiArtData | pred: RealArt (conf 0.923)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/lensa-ai-portrait-2.jpg | true: AiArtData | pred: RealArt (conf 0.930)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/The-Lensa-app-generates-AI-art-but-at-what-cost_-Photo-courtesy-of-Lensa-app.-900x900.jpg | true: AiArtData | pred: RealArt (conf 0.905)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/96715731.jpg | true: AiArtData | pred: RealArt (conf 0.937)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/images77.jpg | true: AiArtData | pred: RealArt (conf 0.907)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/portrait-01.jpg | true: AiArtData | pred: RealArt (conf 0.939)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/79ee7c59b0b2a08f9438487b729469ae.jpg | true: AiArtData | pred: RealArt (conf 0.937)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/GettyImages-1096829784-copy.jpg | true: AiArtData | pred: RealArt (conf 0.940)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/ai-portraits-celebrities-keanu-reeves.jpg | true: AiArtData | pred: RealArt (conf 0.944)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/AI-recreations-of-men-and-women-from-different-sta_1672816365869.jpg | true: AiArtData | pred: RealArt (conf 0.928)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/AI20Landscape.jpg | true: AiArtData | pred: RealArt (conf 0.949)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/2022-11-10-image-12.jpg | true: AiArtData | pred: RealArt (conf 0.940)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/240201-airec-main-ksp-5625e8.jpg | true: AiArtData | pred: RealArt (conf 0.913)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/nvidia-ai-scribbles-realistic-landscapes.png | true: AiArtData | pred: RealArt (conf 0.928)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/AIArtRoundupFeatured-1200x675.png | true: AiArtData | pred: RealArt (conf 0.912)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/Animals04april2023.jpg | true: AiArtData | pred: RealArt (conf 0.952)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/befunky-collage_58-sixteen_nine.jpg | true: AiArtData | pred: RealArt (conf 0.921)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/Gopnik_ai_art.jpg | true: AiArtData | pred: RealArt (conf 0.928)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/5d395cf1a43bd-ai-transforms-celebrities-photo-into-old-portraits-paintings-5d380beb228da__700.jpg | true: AiArtData | pred: RealArt (conf 0.941)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/1E9WJo1jFlzdGVuFhb4BdQw.png | true: AiArtData | pred: RealArt (conf 0.946)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/1EOlo-3uyfHVlEE649tq62g.png | true: AiArtData | pred: RealArt (conf 0.921)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/ai-images-news.jpg | true: AiArtData | pred: RealArt (conf 0.904)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/il_570xN.4588037671_ak6c.jpg | true: AiArtData | pred: RealArt (conf 0.924)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/Various-AI-portraits-generated-by-Fotor.jpg | true: AiArtData | pred: RealArt (conf 0.913)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/SC-AI-Woman-Off-Plat2-copy-1.jpg | true: AiArtData | pred: RealArt (conf 0.941)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/120522_Lensa_AI.width-696.jpg | true: AiArtData | pred: RealArt (conf 0.947)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/midjourney-tools-tips-for-photographers-photography-photo-realistic.png | true: AiArtData | pred: RealArt (conf 0.938)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/tnsc6ik8_personalities-playing-holi_625x300_18_June_23.jpg | true: AiArtData | pred: RealArt (conf 0.944)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/1662575095617-collage-maker-07-sep-2022-0224-pm.jpeg | true: AiArtData | pred: RealArt (conf 0.940)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/filippo-nassetti-ai-designs-spaceships-bosch-caravaggio-designboom-600.jpg | true: AiArtData | pred: RealArt (conf 0.937)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/07-the-coffee-service-hossaini-art-ai.x3e656121.png | true: AiArtData | pred: RealArt (conf 0.929)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/ai-generated-background-1.jpg | true: AiArtData | pred: RealArt (conf 0.891)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/100960167.jpg | true: AiArtData | pred: RealArt (conf 0.911)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/images21.jpg | true: AiArtData | pred: RealArt (conf 0.912)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/CreationOfAdam.jpg | true: AiArtData | pred: RealArt (conf 0.935)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/ai-portraits-millions-actors-photos-designboom-1200.jpg | true: AiArtData | pred: RealArt (conf 0.959)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/Midjourney-v6.jpeg | true: AiArtData | pred: RealArt (conf 0.931)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/1Mcde2p8rG0uUjwwQ-tGWLg.png | true: AiArtData | pred: RealArt (conf 0.942)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/960x0.jpg | true: AiArtData | pred: RealArt (conf 0.936)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/Flower-Trip-style.jpeg | true: AiArtData | pred: RealArt (conf 0.914)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/How-to-Earn-Money-through-AI-Generated-Artwork-A-Simplified-Guide.jpg | true: AiArtData | pred: RealArt (conf 0.940)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/ai-cartoon-portraits-01.jpg | true: AiArtData | pred: RealArt (conf 0.951)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/4hPwM82KpnA0Rie1400A.jpg | true: AiArtData | pred: RealArt (conf 0.947)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/ai-art-beautiful-psychedelic-colored-angel-with-butterflies-2-rose-santuci-sofranko.jpg | true: AiArtData | pred: RealArt (conf 0.937)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/Julian-van-Dieken_A-Girl-With-Glowing-Earrings-.png | true: AiArtData | pred: RealArt (conf 0.941)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/1344278.jpg | true: AiArtData | pred: RealArt (conf 0.893)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/flat750x075f-pad750x1000f8f8f8.u2.jpg | true: AiArtData | pred: RealArt (conf 0.937)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/ai-faces-white.jpg | true: AiArtData | pred: RealArt (conf 0.940)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/Bu69yrI45ueNWQX84ap5.jpg | true: AiArtData | pred: RealArt (conf 0.951)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/images88.jpg | true: AiArtData | pred: RealArt (conf 0.916)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/fdfs2-800x533.jpg | true: AiArtData | pred: RealArt (conf 0.946)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/1fu-PkIWiOiMMedfiGmFefg.jpeg | true: AiArtData | pred: RealArt (conf 0.920)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/aiart.png | true: AiArtData | pred: RealArt (conf 0.928)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/2K65J19-2.jpg | true: AiArtData | pred: RealArt (conf 0.927)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/wonderland-girl-generated-by-Fotor-ai-art-generator.jpg | true: AiArtData | pred: RealArt (conf 0.938)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/EmaqLSjrm4SBsK7Xspie--1--avr9b.jpg | true: AiArtData | pred: RealArt (conf 0.928)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/1000_F_555746402_GNMEIKpEuTIXooW5B1SEEy7VnK3rklI5.jpg | true: AiArtData | pred: RealArt (conf 0.943)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/elijah-clean28129-1.png | true: AiArtData | pred: RealArt (conf 0.935)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/1u7_j9GJ8BuLJv529Og-Tgg.png | true: AiArtData | pred: RealArt (conf 0.944)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/name320.png | true: AiArtData | pred: RealArt (conf 0.932)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/5d395cf1e10ca-ai-transforms-celebrities-photo-into-old-portraits-paintings-5d380c3722b84__700.jpg | true: AiArtData | pred: RealArt (conf 0.947)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/AI_image.png | true: AiArtData | pred: RealArt (conf 0.915)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/43div2to_animal-selfies_625x300_03_April_23.jpg | true: AiArtData | pred: RealArt (conf 0.929)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/banner-of-AI-Landscape-Generator_2023-05-25-100511_xmkz.jpg | true: AiArtData | pred: RealArt (conf 0.914)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/GANimal-1280x540.jpg | true: AiArtData | pred: RealArt (conf 0.953)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/ai-generated-8260240_1280.jpg | true: AiArtData | pred: RealArt (conf 0.932)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/y5aca20it7v1kb9qs0ce.jpg | true: AiArtData | pred: RealArt (conf 0.960)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/midjourney_young_woman_61b02a5d-6935-44aa-842c-8f5e84f4c702-1024x1024.png | true: AiArtData | pred: RealArt (conf 0.944)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/image14.jpeg | true: AiArtData | pred: RealArt (conf 0.925)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/psychedelic-artistic-image-christmas-santa-260nw-2401991075.jpg | true: AiArtData | pred: RealArt (conf 0.927)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/52520977911_33437880be_z.jpg | true: AiArtData | pred: RealArt (conf 0.934)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/NVIDIA-GauGAN-AI-demo-screenshot.jpg | true: AiArtData | pred: RealArt (conf 0.952)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/ai-last-selfie-taken-earth-comp.jpg | true: AiArtData | pred: RealArt (conf 0.943)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/Dark-Side-of-the-Moon-AI.jpg | true: AiArtData | pred: RealArt (conf 0.956)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/chicken-1024x683.jpg | true: AiArtData | pred: RealArt (conf 0.947)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/ai-art-illustration-landscape-hd-wallpaper-preview.jpg | true: AiArtData | pred: RealArt (conf 0.915)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/nqsvevjgn3gxdubar6ly.JPEG.jpg | true: AiArtData | pred: RealArt (conf 0.936)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/hwXBAos.jpg | true: AiArtData | pred: RealArt (conf 0.946)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/ake-underwater-landscape-background-adventure-explore-vibe-graphic-art-photo.jpg | true: AiArtData | pred: RealArt (conf 0.945)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/2A8oNV0baUgW9iGIEk1X.jpg | true: AiArtData | pred: RealArt (conf 0.949)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/MicrosoftTeams-image551ad57e01403f080a9df51975ac40b6efba82553c323a742b42b1c71c1e45f1.jpg | true: AiArtData | pred: RealArt (conf 0.928)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/18871730-0-image-a-27_1569333047511.jpg | true: AiArtData | pred: RealArt (conf 0.943)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/a-3-718x523.jpeg | true: AiArtData | pred: RealArt (conf 0.937)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/hXN3TDj3BCU8aYUFBbKG_5.3945x.jpg | true: AiArtData | pred: RealArt (conf 0.932)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/Worlds-First-AI-Generated-Art-Gallery-in-Amsterdam.jpg | true: AiArtData | pred: RealArt (conf 0.936)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/ting-art-on-a-canvas-with-many-colors-in-art-nouveau-style-1-e1670998298608.jpeg | true: AiArtData | pred: RealArt (conf 0.925)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/chrischilek_let_your_mind_wonder_7918d619-e9c8-4374-93fb-2468f1c54130.png | true: AiArtData | pred: RealArt (conf 0.901)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/Top-7-Amazing-Artworks-Meet-the-AI-Art-Makers-of-the-Future-AI-generated-eyes_face-of-a-woman.jpg | true: AiArtData | pred: RealArt (conf 0.922)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/ai-portrait-10.jpg | true: AiArtData | pred: RealArt (conf 0.930)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/ai-art-voguebus-photographer-month-22-story.jpg | true: AiArtData | pred: RealArt (conf 0.947)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/Ai-Da-robot-AI-art-hed.jpg | true: AiArtData | pred: RealArt (conf 0.946)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/Midjourney-Mishra-abstract-dancing-painting.jpg | true: AiArtData | pred: RealArt (conf 0.891)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/How-to-Use-Midjourney-to-create-AI-Art.jpg | true: AiArtData | pred: RealArt (conf 0.938)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/HD-wallpaper-artwork-midjourney-ai-ai-generated-nature-landscape-mountains-resolution.jpg | true: AiArtData | pred: RealArt (conf 0.908)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/Header-2.jpg | true: AiArtData | pred: RealArt (conf 0.951)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/41b6d9592db18a15b1e32dfd50.jpg | true: AiArtData | pred: RealArt (conf 0.950)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/top_5_midjourney_artists_2_1.jpg | true: AiArtData | pred: RealArt (conf 0.879)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/Vincent-progress.jpg | true: AiArtData | pred: RealArt (conf 0.920)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/trippy-psychedelic-artwork-retro-hippie-style-generative-ai-surreal-landscape-274005108.jpg | true: AiArtData | pred: RealArt (conf 0.941)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/737a36cc-c873-4451-90a5-271f2eae7778_landing-ai-portrait-img-3.png | true: AiArtData | pred: RealArt (conf 0.944)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/1000_F_588347899_rcxPfuXCi7gXABcOl1TuboinIVfa6ggf.jpg | true: AiArtData | pred: RealArt (conf 0.944)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/03a3gbCKfH8dDJnjhHLuHDf-1.fit_lim.v1665523315.png | true: AiArtData | pred: RealArt (conf 0.915)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/ancient_thing_when_the_leaves_take_thei_a1c8ef7e-e531-4d0d-8bcf-e5714b420f8e.png | true: AiArtData | pred: RealArt (conf 0.932)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/ai-generated-8067660_1280.jpg | true: AiArtData | pred: RealArt (conf 0.925)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/0nglsAEPlxapCcJZA.jpeg | true: AiArtData | pred: RealArt (conf 0.939)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/640px-22Mona_Lisa22_with_DeepDream_effect_using_VGG16_network_trained_on_ImageNet.jpg | true: AiArtData | pred: RealArt (conf 0.919)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/wp-image-940-16849365973x2.jpg | true: AiArtData | pred: RealArt (conf 0.934)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/-using-generative-ai-technology-landscape-pattern-abstract-concept-269270897.jpg | true: AiArtData | pred: RealArt (conf 0.926)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/ai-generated-animal-crossbreeds-09.jpg | true: AiArtData | pred: RealArt (conf 0.925)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/Instagram_Viral_Image_AI_Cat_Dog_1680332724335_1680332736162_1680332736162.png | true: AiArtData | pred: RealArt (conf 0.932)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/maxresdefault3.jpg | true: AiArtData | pred: RealArt (conf 0.908)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/meditation-kundalini-energy-colorful-psychedelic-ai-generated-art_843679-6229.jpg | true: AiArtData | pred: RealArt (conf 0.926)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/ai-generated-photos-1514935235304-videoSixteenByNineJumbo1600-v4.jpg | true: AiArtData | pred: RealArt (conf 0.933)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/on-ai-generated-beautiful-flowers-scenery-spring-season-background-293527034.jpg | true: AiArtData | pred: RealArt (conf 0.960)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/beautiful-psychedelic-surreal-landscape-water-painting-ai-generated-art_843679-2401.jpg | true: AiArtData | pred: RealArt (conf 0.938)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/Nov20_17_498430921.jpg | true: AiArtData | pred: RealArt (conf 0.945)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/ai-generated-7787714_1280.jpg | true: AiArtData | pred: RealArt (conf 0.884)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/1DUblwf5wpci3hVlmG4ZnDw.png | true: AiArtData | pred: RealArt (conf 0.949)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/AdobeStock_559145847.jpeg | true: AiArtData | pred: RealArt (conf 0.937)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/an-ai-jungle-landscape-made-by-ai-landscape-generator.jpg | true: AiArtData | pred: RealArt (conf 0.924)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/5d395cf120e51-ai-transforms-celebrities-photo-into-old-portraits-paintings-5d380c2ebd006__700.jpg | true: AiArtData | pred: RealArt (conf 0.947)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/earing-a-yellow-kimono-in-a-beautiful-and-foggy-tropical-greenh-copy-800x800.jpg | true: AiArtData | pred: RealArt (conf 0.933)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/il_570xN.4707958416_2553.jpg | true: AiArtData | pred: RealArt (conf 0.938)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/1OeeE1RRVpzeCUyD030s8Kg.png | true: AiArtData | pred: RealArt (conf 0.891)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/GoogleAI-theAIgang.jpg | true: AiArtData | pred: RealArt (conf 0.941)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/1000_F_570271411_Tqbdg5z0mL3qV3eaDS0XGrjMMwk6aNTf.jpg | true: AiArtData | pred: RealArt (conf 0.947)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/baby-ping.jpg | true: AiArtData | pred: RealArt (conf 0.951)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/Midjourney-2.png | true: AiArtData | pred: RealArt (conf 0.915)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/104023917.jpg | true: AiArtData | pred: RealArt (conf 0.942)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/midjourney_v4_hero_2-640x360.jpg | true: AiArtData | pred: RealArt (conf 0.949)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/Realistic-Images.jpg | true: AiArtData | pred: RealArt (conf 0.955)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/335893730_1248848252414001_2214479283759117231_n_1679724354609_1679724368314_1679724368314.jpg | true: AiArtData | pred: RealArt (conf 0.932)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/6324662e5ee3110438933c1b_COBE-Pink-Elephant-Midjourney-Article.jpg | true: AiArtData | pred: RealArt (conf 0.930)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/file-20220421-24-mcdm2i.jpg | true: AiArtData | pred: RealArt (conf 0.839)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/07IHO-LENSA-TOPART-articleLarge.jpg | true: AiArtData | pred: RealArt (conf 0.918)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/1687776010494_Screenshot20230626160839.png | true: AiArtData | pred: RealArt (conf 0.940)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/memory-palace-by-Louis-Vivin-250_out-1.png | true: AiArtData | pred: RealArt (conf 0.945)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/psychedelic-image-edited-2.png | true: AiArtData | pred: RealArt (conf 0.936)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/196027s_art_of_cow_getting_abducted_by_UFO_in_midwest.jpg | true: AiArtData | pred: RealArt (conf 0.951)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/ai-generated-human-2.png | true: AiArtData | pred: RealArt (conf 0.925)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/create-ai-landscapes-with-ai-landscape-generator-of-fotor.jpg | true: AiArtData | pred: RealArt (conf 0.955)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/banner-img2.png | true: AiArtData | pred: RealArt (conf 0.955)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/portraits.jpg | true: AiArtData | pred: RealArt (conf 0.908)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/e47d1283-90b0-4844-98a3-41456f0c341c.jpg | true: AiArtData | pred: RealArt (conf 0.928)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/AI-generated-art-copyright.jpg | true: AiArtData | pred: RealArt (conf 0.930)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/1a9B6fCE7uFAgaQDUMGFRqw.jpeg | true: AiArtData | pred: RealArt (conf 0.912)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/3c958e87e755ddec3003722eb91e787a.jpg | true: AiArtData | pred: RealArt (conf 0.922)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/i7fdm8o8_ai-pics_625x300_10_March_23.jpg | true: AiArtData | pred: RealArt (conf 0.931)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/B49447D3-BE5D-4A25-8505059961823425_source.jpg | true: AiArtData | pred: RealArt (conf 0.947)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/3FUI5P53A5JRLCB432NGJMWTMU.jpg | true: AiArtData | pred: RealArt (conf 0.944)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/tr71123-ai-art.jpeg | true: AiArtData | pred: RealArt (conf 0.947)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/62bf08968c2d68a06b1c7182_image9201-min.jpg | true: AiArtData | pred: RealArt (conf 0.933)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/sddefault2.jpg | true: AiArtData | pred: RealArt (conf 0.945)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/a1ecf33fc27a086ef0120e46385f.jpg | true: AiArtData | pred: RealArt (conf 0.944)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/64efd48f24bacac40feae0b4_qFcGNfN66Fp4nrvBHhQp89Kg425rczlCMKCbW2cNCCs.jpeg | true: AiArtData | pred: RealArt (conf 0.878)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/Portrait_female_Midjourney.jpg | true: AiArtData | pred: RealArt (conf 0.940)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/erreurs-images.jpg | true: AiArtData | pred: RealArt (conf 0.955)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/4D0B10FA-D43F-427A-8F12-084A42A52081-63ef4da8f2ef6-jpeg__700.jpg | true: AiArtData | pred: RealArt (conf 0.934)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/1IGvTkw48FTa1pO33VbG4eA.png | true: AiArtData | pred: RealArt (conf 0.958)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/bDSF6saJUuPLsEu9i3ud--1--gvs7i.jpg | true: AiArtData | pred: RealArt (conf 0.941)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/221206-lensa-selfies-ai-celebrities-cs-548f22.jpg | true: AiArtData | pred: RealArt (conf 0.909)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/midjourney20images.jpg | true: AiArtData | pred: RealArt (conf 0.946)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/Group_12467.jpg | true: AiArtData | pred: RealArt (conf 0.933)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/tr_20240201-the-complete-generative-ai-art-design-mastery-bundle.jpg | true: AiArtData | pred: RealArt (conf 0.902)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/ai20images20holi20vrindavan1687103503681.jpg | true: AiArtData | pred: RealArt (conf 0.939)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/8A0B55B5-A6CA-4440-AA2D-C63CA9E904E0-768x1024.jpeg | true: AiArtData | pred: RealArt (conf 0.944)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/230209101637-malik-afegbua-ngochola-younger.jpg | true: AiArtData | pred: RealArt (conf 0.930)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/ai_image_landscape_12x.png | true: AiArtData | pred: RealArt (conf 0.939)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/UNfSEPwoEvvYcUN4H7PR.jpg | true: AiArtData | pred: RealArt (conf 0.934)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/amazonaws.com2Fpublic2Fimages2Fc5e787c1-70fc-4178-9f18-497c6ec85f79_832x832.jpeg | true: AiArtData | pred: RealArt (conf 0.952)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/illustrator-fantasy-world-scenery-japan-with-mountain-generate-ai_661039-1069.jpg | true: AiArtData | pred: RealArt (conf 0.913)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/Midjourney-guide-explained-how-to-use-370x490.jpg | true: AiArtData | pred: RealArt (conf 0.947)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/oeuvre-art-generee-IA-MidJourney-remporte-1er-prix-Colorado-State-Fair.png | true: AiArtData | pred: RealArt (conf 0.937)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/tunning-double-exposure-landscape-featuring-a-river-trees-and-feathers-photo.jpg | true: AiArtData | pred: RealArt (conf 0.949)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/Midjourney-River.jpg | true: AiArtData | pred: RealArt (conf 0.925)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/images82.jpg | true: AiArtData | pred: RealArt (conf 0.933)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/skynews-ai-art-generator-tim-flach_6121312.jpg | true: AiArtData | pred: RealArt (conf 0.922)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/Lensa20AI20portraits202.jpg | true: AiArtData | pred: RealArt (conf 0.894)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/ai-generated-7768378_1280.jpg | true: AiArtData | pred: RealArt (conf 0.952)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/wieland_hero_2-800x450.jpg | true: AiArtData | pred: RealArt (conf 0.920)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/nXLRsgDqpZcqChDus9b1_9.4899x.jpg | true: AiArtData | pred: RealArt (conf 0.940)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/luke-wells-luke-wells-landscape-midjourney.jpg | true: AiArtData | pred: RealArt (conf 0.885)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/Kai-painting-2023.png | true: AiArtData | pred: RealArt (conf 0.937)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/image13.jpeg | true: AiArtData | pred: RealArt (conf 0.942)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/AI-historical-faces-body-image-1.jpg | true: AiArtData | pred: RealArt (conf 0.938)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/AiArtData/AiArtData/rad0ujy1GFGKCCMD6GhR--1--yh4jv_8x.jpg | true: AiArtData | pred: RealArt (conf 0.930)
# ...
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/RealArt/RealArt/4-23-4-22-8-4-13m.jpg | true: RealArt | pred: RealArt (conf 0.941)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/RealArt/RealArt/a9cb4b9875143b1568ba519ea086af95.png | true: RealArt | pred: RealArt (conf 0.920)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/RealArt/RealArt/homepage-usp-photo-2_600x.jpg | true: RealArt | pred: RealArt (conf 0.950)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/RealArt/RealArt/33100scr.jpg | true: RealArt | pred: RealArt (conf 0.927)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/RealArt/RealArt/getty_511618259_186076.jpg | true: RealArt | pred: RealArt (conf 0.933)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/RealArt/RealArt/sunset-trees-abstract-painting-3.jpg | true: RealArt | pred: RealArt (conf 0.943)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/RealArt/RealArt/scenery-4nho1u78dzvt1meo.jpg | true: RealArt | pred: RealArt (conf 0.884)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/RealArt/RealArt/-man-sits-with-a-woman-on-her-phone-at-a-table-while-looking-at-a-computer_l.jpg | true: RealArt | pred: RealArt (conf 0.959)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/RealArt/RealArt/extinctions_elephants-555x507.jpg | true: RealArt | pred: RealArt (conf 0.946)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/RealArt/RealArt/people-rocco-giannetti-2023-2000x1125_1682531615_1024x576.jpg | true: RealArt | pred: RealArt (conf 0.906)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/RealArt/RealArt/180222162827-the-kiss-story-top-card-image.jpg | true: RealArt | pred: RealArt (conf 0.939)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/RealArt/RealArt/michael_b._jordan_cannes_2018.jpg | true: RealArt | pred: RealArt (conf 0.947)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/RealArt/RealArt/pleaser.jpeg | true: RealArt | pred: RealArt (conf 0.934)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/RealArt/RealArt/b3e341d8ba10a7869442ef08b9fb7663f1ff31aa-aout2019-en.png | true: RealArt | pred: RealArt (conf 0.930)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/RealArt/RealArt/360_F_568525285_CrGJ8Yh1noTyqu6QsocfVeGQGY91E0Jb.jpg | true: RealArt | pred: RealArt (conf 0.908)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/RealArt/RealArt/images6.jpg | true: RealArt | pred: RealArt (conf 0.935)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/RealArt/RealArt/Close_1969.16.jpg | true: RealArt | pred: RealArt (conf 0.946)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/RealArt/RealArt/il_570xN.354623508_9g1k.jpg | true: RealArt | pred: RealArt (conf 0.938)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/RealArt/RealArt/paintings-by-el-greco-franz-marc-cezanne-bruegel.jpg | true: RealArt | pred: RealArt (conf 0.888)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/RealArt/RealArt/beautiful-natural-scenery-with-a-lake-and-mountains-free-photo.jpg | true: RealArt | pred: RealArt (conf 0.929)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/RealArt/RealArt/Group-of-People.jpg | true: RealArt | pred: RealArt (conf 0.903)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/RealArt/RealArt/portrait-african-american-man_23-2149072179.jpg | true: RealArt | pred: RealArt (conf 0.940)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/RealArt/RealArt/daniel-norton-portrait-photography-CLOSE.jpg | true: RealArt | pred: RealArt (conf 0.953)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/RealArt/RealArt/pexels-photo-2598024.jpeg | true: RealArt | pred: RealArt (conf 0.920)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/RealArt/RealArt/gh-famous-latinx-people-1631046697.png | true: RealArt | pred: RealArt (conf 0.939)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/RealArt/RealArt/people-taking-selfie-together-registration-day_23-2149096795.jpg | true: RealArt | pred: RealArt (conf 0.909)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/RealArt/RealArt/pexels-photo-4029925.jpeg | true: RealArt | pred: RealArt (conf 0.938)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/RealArt/RealArt/GettyImages-450753839_83740.jpg | true: RealArt | pred: RealArt (conf 0.941)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/RealArt/RealArt/69601536314088.jpg | true: RealArt | pred: RealArt (conf 0.891)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/RealArt/RealArt/Untitled-design-2022-09-06T133056.012.png | true: RealArt | pred: RealArt (conf 0.957)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/RealArt/RealArt/girl-with-a-pearl-earring-c-16.jpg | true: RealArt | pred: RealArt (conf 0.942)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/RealArt/RealArt/0182.png | true: RealArt | pred: RealArt (conf 0.934)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/RealArt/RealArt/portrait-smiling-middle-aged-african-260nw-2088822202.jpg | true: RealArt | pred: RealArt (conf 0.937)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/RealArt/RealArt/rk-beautiful-autumn-scenery-park-outdoor-photography-sunrise-light-101482086.jpg | true: RealArt | pred: RealArt (conf 0.949)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/RealArt/RealArt/fw-fox-squirrel.jpg | true: RealArt | pred: RealArt (conf 0.936)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/RealArt/RealArt/images31.jpg | true: RealArt | pred: RealArt (conf 0.937)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/RealArt/RealArt/cheetah-003.jpg | true: RealArt | pred: RealArt (conf 0.942)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/RealArt/RealArt/360_F_196873357_Z8LRgbrFSLloSUP1QEqaVAi3OBbVIaWh.jpg | true: RealArt | pred: RealArt (conf 0.958)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/RealArt/RealArt/Portrait197a-1280x640.jpg | true: RealArt | pred: RealArt (conf 0.939)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/RealArt/RealArt/images9.jpg | true: RealArt | pred: RealArt (conf 0.936)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/RealArt/RealArt/gettyimages-1238924365_wide-b1f7435f5e1e69d0b3a32ad364de7204c89cc15e-s1100-c50.jpg | true: RealArt | pred: RealArt (conf 0.924)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/RealArt/RealArt/il_570xN.1185533356_i5n8.jpg | true: RealArt | pred: RealArt (conf 0.914)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/RealArt/RealArt/scenery.jpg | true: RealArt | pred: RealArt (conf 0.946)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/RealArt/RealArt/set-safari-animals-illustration-600nw-2150029883.jpg | true: RealArt | pred: RealArt (conf 0.947)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/RealArt/RealArt/Jason-Brown-lemur-baby.jpg | true: RealArt | pred: RealArt (conf 0.934)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/RealArt/RealArt/dwayne-johnson-attends-the-premiere-of-universal-pictures-news-photo-1161880409-1566504158.jpg | true: RealArt | pred: RealArt (conf 0.947)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/RealArt/RealArt/contemporary-realism-portrait-painting-Stanley-Rayfield-artist-Churchhatnew-scaled.jpg | true: RealArt | pred: RealArt (conf 0.948)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/RealArt/RealArt/il_570xN.4398975758_9o5j.jpg | true: RealArt | pred: RealArt (conf 0.945)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/RealArt/RealArt/WI110119_W25_32.jpg | true: RealArt | pred: RealArt (conf 0.946)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/RealArt/RealArt/why_we_connect_with_vincent_van_goghs_paintings_1050x700.jpg | true: RealArt | pred: RealArt (conf 0.915)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/RealArt/RealArt/HD-wallpaper-scenery-lake-nature-sky-tree-water.jpg | true: RealArt | pred: RealArt (conf 0.869)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/RealArt/RealArt/pngtree-beautiful-natural-scenery-like-in-a-fairyland-used-as-phone-wallpaper-image_1949463.jpg | true: RealArt | pred: RealArt (conf 0.935)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/RealArt/RealArt/final_animals-homeschooling_credit-alamy.jpg | true: RealArt | pred: RealArt (conf 0.960)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/RealArt/RealArt/capy1.png | true: RealArt | pred: RealArt (conf 0.932)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/RealArt/RealArt/Chris-Pratt.jpg | true: RealArt | pred: RealArt (conf 0.911)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/RealArt/RealArt/unknown-artist-mountain-landscapes-oil-on-card-paintings-set-of-2-8.jpg | true: RealArt | pred: RealArt (conf 0.947)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/RealArt/RealArt/Africa-2.png | true: RealArt | pred: RealArt (conf 0.933)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/RealArt/RealArt/portrait-young-beautiful-woman-perfect-600nw-2228044151.jpg | true: RealArt | pred: RealArt (conf 0.912)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/RealArt/RealArt/mountainpygmypossum_science_BCDJ6K.jpg | true: RealArt | pred: RealArt (conf 0.913)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/RealArt/RealArt/tiger-full-width.jpg.thumb.1160.1160.jpg | true: RealArt | pred: RealArt (conf 0.935)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/RealArt/RealArt/il_570xN.3757074450_o5mt.jpg | true: RealArt | pred: RealArt (conf 0.950)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/RealArt/RealArt/images.jpg | true: RealArt | pred: RealArt (conf 0.939)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/RealArt/RealArt/images43.jpg | true: RealArt | pred: RealArt (conf 0.940)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/RealArt/RealArt/5c09c4dc82dc441dfb26975fe8dc1634.jpg | true: RealArt | pred: RealArt (conf 0.913)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/RealArt/RealArt/female-face-eye-level-portrait.jpg | true: RealArt | pred: RealArt (conf 0.939)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/RealArt/RealArt/thumb-duiker-animal.jpg | true: RealArt | pred: RealArt (conf 0.930)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/RealArt/RealArt/H0820-L360654254.jpg | true: RealArt | pred: RealArt (conf 0.918)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/RealArt/RealArt/african-spurred-tortoise-web-image-300x200.jpg | true: RealArt | pred: RealArt (conf 0.922)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/RealArt/RealArt/forest-landscape_71767-127.jpg | true: RealArt | pred: RealArt (conf 0.859)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/RealArt/RealArt/6170a8ed-8180-448b-8cd1-faaa035fd5c6_570.Jpeg.jpg | true: RealArt | pred: RealArt (conf 0.927)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/RealArt/RealArt/beautiful-nature-scenery-smartphone-wallpaper-free-photo.jpg | true: RealArt | pred: RealArt (conf 0.913)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/RealArt/RealArt/p5quSf4dZXctG9WFepXFdR-1200-80.jpg | true: RealArt | pred: RealArt (conf 0.941)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/RealArt/RealArt/1032249.jpg | true: RealArt | pred: RealArt (conf 0.930)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/RealArt/RealArt/beautiful-nature-scenery-free-photo.jpg | true: RealArt | pred: RealArt (conf 0.953)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/RealArt/RealArt/evelyn-bradley.jpg | true: RealArt | pred: RealArt (conf 0.940)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/RealArt/RealArt/131207210_web1_20230506dj-littiken-1.jpg | true: RealArt | pred: RealArt (conf 0.951)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/RealArt/RealArt/812EtDiEY9L._AC_UF10001000_QL80_.jpg | true: RealArt | pred: RealArt (conf 0.907)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/RealArt/RealArt/1997.166-GAP.jpg | true: RealArt | pred: RealArt (conf 0.918)
# /home/luis-menezes/.cache/kagglehub/datasets/cashbowman/ai-generated-images-vs-real-images/versions/1/RealArt/RealArt/1200x0.jpg | true: RealArt | pred: RealArt (conf 0.950)
#
# Overall accuracy (using parent-folder labels): 0.4474 (434/970)
# Per-class accuracy:
#   AiArtData: 0/536 = 0.0000
#   RealArt: 434/434 = 1.0000

# %%
from matplotlib import pyplot as plt
import numpy as np
import requests
try:
    labels_url = "https://raw.githubusercontent.com/pytorch/hub/master/imagenet_classes.txt"
    labels_file = requests.get(labels_url).text.split("\n")
except Exception as e:
    print(f"Erro ao baixar labels: {e}")
    # Fallback se a internet falhar na apresentação
    labels_file = ["Label N/A"] * 1000

# Função para prever (classificar) a imagem
def predict(image_tensor, top_k=1):
    with torch.no_grad(): # Não calcular gradientes na inferência normal
        output = model(image_tensor)
        probabilities = F.softmax(output, dim=1)
        top_prob, top_indices = torch.topk(probabilities, top_k)
        
        for i in range(top_k):
            label = labels_file[top_indices[0][i]]
            prob = top_prob[0][i].item() * 100
            print(f"Predição {i+1}: {label} (Confiança: {prob:.2f}%)")
    return top_indices[0][0] # Retorna o índice da classe principal

# Função para mostrar a imagem (desnormalizando)
def show_image(tensor, title=""):
    # Desnormalizar a imagem para visualização
    tensor = tensor.clone().detach().cpu().squeeze(0)
    inv_normalize = transforms.Normalize(
        mean=[-0.485/0.229, -0.456/0.224, -0.406/0.225],
        std=[1/0.229, 1/0.224, 1/0.225]
    )
    img = inv_normalize(tensor)
    img = img.permute(1, 2, 0) # Mudar de [C, H, W] para [H, W, C]
    img = np.clip(img, 0, 1) # Garantir que os valores estão entre 0 e 1
    plt.imshow(img)
    plt.title(title)
    plt.axis('off')
    plt.show()
